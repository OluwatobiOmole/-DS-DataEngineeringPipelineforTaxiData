# %%
import pandas as pd

# %%
df = pd.read_csv('sample_5mb.csv')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-02-25 17:24:20   2016-02-25 17:27:20                2
# 1         2  2016-02-25 23:10:50   2016-02-25 23:31:50                2
# 2         2  2016-02-01 00:00:01   2016-02-01 00:10:52                6
# 3         1  2016-02-01 00:00:04   2016-02-01 00:05:16                1
# 4         2  2016-02-01 00:00:05   2016-02-01 00:20:59                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           0.70        -73.947250        40.763771           1
# 1           5.52        -73.983017        40.750992           1
# 2           1.99        -73.992340        40.758202           1
# 3           1.50        -73.981453        40.749722           1
# 4           5.60        -74.000603        40.729755           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.992012         40.735390           2.0
# 1                  N         -73.988586         40.758839           2.0
# 2                  N         -73.964355         40.757977           1.0
# 3                  N         -73.982323         40.763985           2.0
# 4                  N         -73.951324         40.669834           1.0
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          5.0    0.0      0.5         0.0           0.0
# 1         20.0    0.5      0.5         0.0           0.0
# 2          9.5    0.5      0.5         0.7           0.0
# 3          6.5    0.5      0.5         0.0           0.0
# 4         20.0    0.5      0.5         4.0           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3           5.8
# 1                    0.3          21.3
# 2                    0.3          11.5
# 3                    0.3           7.8
# 4                    0.3          25.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33181 entries, 0 to 33180
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               33181 non-null  int64
#  1   tpep_pickup_datetime   33181 non-null  object
#  2   tpep_dropoff_datetime  33181 non-null  object
#  3   passenger_count        33181 non-null  int64
#  4   trip_distance          33181 non-null  float64
#  5   pickup_longitude       33181 non-null  float64
#  6   pickup_latitude        33181 non-null  float64
#  7   RatecodeID             33181 non-null  int64
#  8   store_and_fwd_flag     33181 non-null  object
#  9   dropoff_longitude      33181 non-null  float64
#  10  dropoff_latitude       33181 non-null  float64
#  11  payment_type           33180 non-null  float64
#  12  fare_amount            33180 non-null  float64
#  13  extra                  33180 non-null  float64
#  14  mta_tax                33180 non-null  float64
#  15  tip_amount             33180 non-null  float64
#  16  tolls_amount           33180 non-null  float64
#  17  improvement_surcharge  33180 non-null  float64
#  18  total_amount           33180 non-null  float64
# dtypes: float64(13), int64(3), object(3)
# memory usage: 4.8+ MB

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
df = df.drop_duplicates().reset_index(drop=True)
df['trip_id'] = df.index

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-02-25 17:24:20   2016-02-25 17:27:20                2
# 1         2  2016-02-25 23:10:50   2016-02-25 23:31:50                2
# 2         2  2016-02-01 00:00:01   2016-02-01 00:10:52                6
# 3         1  2016-02-01 00:00:04   2016-02-01 00:05:16                1
# 4         2  2016-02-01 00:00:05   2016-02-01 00:20:59                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           0.70        -73.947250        40.763771           1
# 1           5.52        -73.983017        40.750992           1
# 2           1.99        -73.992340        40.758202           1
# 3           1.50        -73.981453        40.749722           1
# 4           5.60        -74.000603        40.729755           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.992012         40.735390           2.0
# 1                  N         -73.988586         40.758839           2.0
# 2                  N         -73.964355         40.757977           1.0
# 3                  N         -73.982323         40.763985           2.0
# 4                  N         -73.951324         40.669834           1.0
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          5.0    0.0      0.5         0.0           0.0
# 1         20.0    0.5      0.5         0.0           0.0
# 2          9.5    0.5      0.5         0.7           0.0
# 3          6.5    0.5      0.5         0.0           0.0
# 4         20.0    0.5      0.5         4.0           0.0
#
#    improvement_surcharge  total_amount  trip_id
# 0                    0.3           5.8        0
# 1                    0.3          21.3        1
# 2                    0.3          11.5        2
# 3                    0.3           7.8        3
# 4                    0.3          25.3        4

# %%
datetime_dim = df[['tpep_pickup_datetime','tpep_dropoff_datetime']].reset_index(drop=True)
datetime_dim['tpep_pickup_datetime'] = datetime_dim['tpep_pickup_datetime']
datetime_dim['pick_hour'] = datetime_dim['tpep_pickup_datetime'].dt.hour
datetime_dim['pick_day'] = datetime_dim['tpep_pickup_datetime'].dt.day
datetime_dim['pick_month'] = datetime_dim['tpep_pickup_datetime'].dt.month
datetime_dim['pick_year'] = datetime_dim['tpep_pickup_datetime'].dt.year
datetime_dim['pick_weekday'] = datetime_dim['tpep_pickup_datetime'].dt.weekday

# %%
datetime_dim['drop_hour'] = datetime_dim['tpep_dropoff_datetime'].dt.hour
datetime_dim['drop_day'] = datetime_dim['tpep_dropoff_datetime'].dt.day
datetime_dim['drop_month'] = datetime_dim['tpep_dropoff_datetime'].dt.month
datetime_dim['drop_year'] = datetime_dim['tpep_dropoff_datetime'].dt.year
datetime_dim['drop_weekday'] = datetime_dim['tpep_dropoff_datetime'].dt.weekday

# %%
datetime_dim['datetime_id'] = datetime_dim.index
